# %%
import numpy as np # linaer algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
#df = df.iloc[: ,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 33    28            44000          0
# 236   40            57000          0
# 283   52            21000          1
# 349   38            61000          0
# 25    47            20000          1

# %% [markdown]
# **comparison distributions**

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# given data has no outlieners .....but to show the outlieners we could add   verying data from itself

# %%
new_data = pd.DataFrame({
    'Age': [5, 90, 95],
    'EstimatedSalary': [1000, 250000, 350000],
    'Purchased': [0, 1, 1]})

df = pd.concat([df, new_data], ignore_index=True)

# %% [markdown]
# by above functions we have appended nwe data at existing one to show trhe outliers

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
plt.scatter(df['Age'] , df['EstimatedSalary'])

# %% [markdown]
# when to use Standarisation ......
#  when algorithms like
#  k - means
#  k - nearest neighbours
#  principal component analysis
#  gradient descent
