# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 v = pd.read_csv('/content/data.csv')

# %%
v
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            8.0              0.50         0.39            2.20
# 1        1            9.3              0.30         0.73            2.30
# 2        2            7.1              0.51         0.03            2.10
# 3        3            8.1              0.87         0.22            2.60
# 4        4            8.5              0.36         0.30            2.30
# ...    ...            ...               ...          ...             ...
# 2051  2051            6.6              0.31         0.13            2.00
# 2052  2052            9.7              0.59         0.21            1.80
# 2053  2053            7.7              0.43         0.42            1.70
# 2054  2054            9.1              0.50         0.00            1.75
# 2055  2055            6.2              0.31         0.18            2.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
selected_v = v[['fixed acidity', 'alcohol', 'quality']]

# %%
print(selected_v)
# Out:
#       fixed acidity  alcohol  quality
# 0               8.0     12.1        6
# 1               9.3     12.8        6
# 2               7.1     11.3        7
# 3               8.1      9.8        5
# 4               8.5      9.5        6
# ...             ...      ...      ...
# 2051            6.6     12.0        7
# 2052            9.7      9.4        5
# 2053            7.7     12.5        8
# 2054            9.1      9.5        5
# 2055            6.2     11.4        7
#
# [2056 rows x 3 columns]

# %%
sns.kdeplot(v['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# above graph telling that in wines  the qauntity of alochol in wine is peak at 9 to 10  means alcohal is in 9 to 10 perecnt in wines and ...also telling that in wines the  the qauntity  of alcohal mostly is in  9 to 11 ... density represent means that between 9 to 12 most concentration of wine quantiuty are at this point ..... between 9 to 11  ...MEANS MOTLY frequents are here

# %%
sns.kdeplot(v['fixed acidity'])
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# "Most wines are clustered around a fixed acidity of approximately 8."
# "This means that wines most frequently have a fixed acidity value close to 8."

# %%
print(v['free sulfur dioxide'].unique())
# Out:
# [30.   3.  11.  10.   6.  18.  17.  13.  23.  31.  16.  12.  25.   5.
#  15.   7.  27.  24.   9.  19.  22.  14.  26.  28.  32.  21.   8.  34.
#  20.  29.  35.   4.  37.5 41.  45.  48.  33.  38.   1.  36.  51.  68.
#  42.  43.  52.  40.5 40.  39.  37. ]
