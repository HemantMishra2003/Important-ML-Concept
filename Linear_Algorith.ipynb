# %%
# linear algorithm is supervised machine learning algorithm
# in supervised we have regression and classification regression
# regression means output column is numerical ....
# and classification

# in supervised we have
# 1.linear regression algorithm
# A.simple lr
# b.multiplel lr
# c.polynomial lr
# d.regularisation lr

# %%
#       simple linear regression

# a. input column
# b. output column

# more than one inputs is known as multiple linear regression model

# %%
# in appropriate simple linear regression we use
# y = mx + c to find oout the ooutputs
#  where m is slope and c is intercept
#   herer c means when x = 0 then y = c   x is  keep varying for y
#   or dependent
#  hence we cant put y values diret to y because when x is 2 may y value is
#  something else ...when y is eqaul to 4 may y value diffre hence y is
#  keep changing ...hence we cant put y value at y ....

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
v = pd.read_csv("/content/placement (1).csv")

# %%
v.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
v.shape
# Out:
# (200, 2)

# %%
plt.scatter(v["cgpa"],v["package"])
plt.xlabel("cgpa")
plt.ylabel("package(in lpa)")
plt.show()

# %%
pip install plotly

# %%
import plotly.express as px

fig = px.scatter(
    v,
    x="cgpa",
    y="package",
    color="cgpa",                   # chhattak rang based on CGPA
    color_continuous_scale="plasma",  # vibrant color theme
    size_max=20,
    title="🌟 CGPA vs Placement Package",
    labels={"cgpa": "CGPA", "package": "Package (LPA)"},
)

fig.update_traces(marker=dict(size=10, line=dict(width=1, color='DarkSlateGrey')))
fig.update_layout(
    plot_bgcolor='white',
    font=dict(size=14),
    title_font=dict(size=20),
    title_x=0.5,
)
fig.show()

## by chatgpt for makling it more beautyful
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = v.iloc[:,0:1]
y = v.iloc[:,-1]

# %%
x.head(1)
# Out:
#    cgpa
# 0  6.89

# %%
y.head(1)
# Out:
# 0    3.26
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# You are splitting your dataset into training and testing parts,
# which is a very important step in Machine Learning.

# x: Features (input data)

# y: Labels (target/output)

# test_size=0.2: 20% data goes into testing, 80% for training

# random_state=2: Ensures the split is repeatable every time
# you run the code (for consistency)

# %%
from sklearn.linear_model import LinearRegression

# %%
Ir = LinearRegression()
# we are making an object for linear regression

# %%
Ir.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))

# we are predicting here iloc 0 means we have  given 1st column of cgpa
# of test but what we got in the results or prediction is that package is jsut
# 3 lakh but actually  by y test we could see that originally package was 4

# bottom line
                  # our model predicted  wrong
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([3.89111601])

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1))
# again model predicted wrong
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([3.09324469])

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))

# yes its  quite somewherre predicted right  we have passed
# test input of 3rd row and given almost accurate from test output
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([2.38464568])

# %%
plt.scatter(v['cgpa'] , v['package'])
plt.plot(x_test,lr.predict(x_test) , color = 'black' )
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')

# nitin sir

# so this is the line which our linear  regression model have
# have fetches out for out bets fit line
# then also our model alos have find out the slope and the intercepets
# too ...lets see the slope of my best fit line ......
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_

# %%
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_

# %%
# we know  the formula of the equations of the Line
# y = mx + c
# so what exactly happened first person cgpa is 8.5
# and  our answer comes or prediction comes out 3.84
# lets see how it came.......
y = m*8.5 + b

# %%
y

# by here we could see that how our best fit line predicted the model
# by the use of linear eqation......
# Out:
# array([3.84647985])

# %%
# so yet we have given test inputs lets give the inputs
# by from our sides
y = m*9.5 + b
y
# here 9.5 is the cgpa.....
# predictng that he would get the 4 lack lpa
# Out:
# array([4.40443183])

# %%
y = m*100 + b

y

# here  100 is the cgpa we have take ...impossible but want
# to see the funny prediction

# and predicted that he get the package of 54 lpa

# here what happens that  we if increase the x then y  too increase
# because our model follow the lines ......like linear equations....
# Out:
# array([54.89908542])

# %%
# so our model searches the best fit lines
# and works by the help of linear eqaution y = mx + c
# y here represents packages  = m*cgpa + b

# here m means  the weightage
# means  how much packages depends over the cg ....
# if m values is quite lesser than package will be quite lesser be dependent
# over the cgpa.
# if m values is quite bigger  than package will be
# quite bigger  be dependent over the cgpa

# go to the soft notes ...on the topic of linear eqaution
